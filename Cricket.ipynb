# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Cricket.xlsx")

# %%
df
# Out:
#               Batsman   Versus Player  Innings  Balls  Outs  Runs  \
# 0    Sachin Tendulkar           B Lee       22    296     7   199
# 1    Sachin Tendulkar      GD McGrath        5     58     2    31
# 2    Sachin Tendulkar        DW Steyn        6     71     0    71
# 3    Sachin Tendulkar   Shoaib Akhtar       11    165     4   138
# 4    Sachin Tendulkar      SM Pollock        8     76     5    13
# ..                ...             ...      ...    ...   ...   ...
# 116               ABD      TM Dilshan       11     92     3    98
# 117               ABD      Wahab Riaz       11    129     0   130
# 118               ABD          Z Khan        9    112     0    91
# 119               ABD  Mohammed Shami        2     28     1    35
# 120   Kumar Sangakara        SK Warne        2     31     0    16
#
#              Bowling Style  5 wkts in an Innings  Bowling Avg  Unnamed: 9  \
# 0           Right Arm Fast                     9        23.36         NaN
# ...

# %%
df.head()
# Out:
#             Batsman  Versus Player  Innings  Balls  Outs  Runs  \
# 0  Sachin Tendulkar          B Lee       22    296     7   199
# 1  Sachin Tendulkar     GD McGrath        5     58     2    31
# 2  Sachin Tendulkar       DW Steyn        6     71     0    71
# 3  Sachin Tendulkar  Shoaib Akhtar       11    165     4   138
# 4  Sachin Tendulkar     SM Pollock        8     76     5    13
#
#            Bowling Style  5 wkts in an Innings  Bowling Avg  Unnamed: 9  \
# 0         Right Arm Fast                     9        23.36         NaN
# 1  Right Arm Fast-Medium                     7        22.02         NaN
# 2         Right Arm Fast                     3        25.95         NaN
# 3         Right Arm Fast                     4        24.97         NaN
# 4  Right Arm Fast-Medium                     5        24.50         NaN
#
#    Unnamed: 10 Unnamed: 11
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN
# 3          NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['Batsman', 'Versus Player', 'Innings', 'Balls', 'Outs', 'Runs',
#        'Bowling Style', '5 wkts in an Innings', 'Bowling Avg', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
df=df.drop(['Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11'],axis=1)

# %%
df
# Out:
#               Batsman   Versus Player  Innings  Balls  Outs  Runs  \
# 0    Sachin Tendulkar           B Lee       22    296     7   199
# 1    Sachin Tendulkar      GD McGrath        5     58     2    31
# 2    Sachin Tendulkar        DW Steyn        6     71     0    71
# 3    Sachin Tendulkar   Shoaib Akhtar       11    165     4   138
# 4    Sachin Tendulkar      SM Pollock        8     76     5    13
# ..                ...             ...      ...    ...   ...   ...
# 116               ABD      TM Dilshan       11     92     3    98
# 117               ABD      Wahab Riaz       11    129     0   130
# 118               ABD          Z Khan        9    112     0    91
# 119               ABD  Mohammed Shami        2     28     1    35
# 120   Kumar Sangakara        SK Warne        2     31     0    16
#
#              Bowling Style  5 wkts in an Innings  Bowling Avg
# 0           Right Arm Fast                     9        23.36
# ...

# %%
df['Batsman'].unique()
# Out:
# array(['Sachin Tendulkar', 'Virat Kohli', 'Brian Lara', 'Kumar Sangakara',
#        'Steven Smith', 'ABD'], dtype=object)

# %%
df['Versus Player'].unique()
# Out:
# array(['B Lee', 'GD McGrath', 'DW Steyn', 'Shoaib Akhtar', 'SM Pollock',
#        'Wasim Akram', 'A Flintoff', 'M Muralitharan', 'PD Collingwood',
#        'Shahid Afridi', 'SL Malinga', 'ST Jayasuriya', 'A Symonds',
#        'Abdul Razzaq', 'CRD Fernando', 'JM Anderson', 'KMDN Kulasekara',
#        'A Zampa', 'AD Mathews', 'CR Woakes', 'GJ Maxwell', 'Imran Tahir',
#        'JO Holder', 'JP Duminy', 'JP Faulkner', 'JR Hazlewood',
#        'KA Pollard', 'K Rabada', 'M Morkel', 'MA Starc', 'MJ Santner',
#        'MP Stoinis', 'NLTC Perera', 'PJ Cummins', 'R Rampaul', 'S Randiv',
#        'Mohammad Amir', 'TG Southee', 'AB Agarkar', 'Harbhajan Singh',
#        'JH Kallis', 'Naved-ul-Hasan', 'WPUJC Vaas', 'A Nehra', 'AF Milne',
#        'DL Vettori', 'GB Hogg', 'I Sharma', 'IK Pathan', 'JDP Oram',
#        'Mashrafe Mortaza', 'MG Johnson', 'MM Patel', 'Mohammad Hafeez',
#        'P Kumar', 'R Ashwin', 'RA Jadeja', 'Saeed Ajmal', 'Shoaib Malik',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = {
    'Batsman': LabelEncoder(),
    'Versus Player': LabelEncoder(),
    'Bowling Style': LabelEncoder()
}

# Fit and transform the data
df['Versus Player'] = label['Versus Player'].fit_transform(df['Versus Player'])

# %% [markdown]
# 'A Flintoff': 0, 'A Nehra': 1, 'A Symonds': 2, 'A Zampa': 3, 'AB Agarkar': 4, 'AD Mathews': 5, 'AF Milne': 6, 'AU Rashid': 7, 'Abdul Razzaq': 8, 'B Kumar': 9, 'B Lee': 10, 'CR Woakes': 11, 'CRD Fernando': 12, 'DL Vettori': 13, 'DW Steyn': 14, 'GB Hogg': 15, 'GD McGrath': 16, 'GJ Maxwell': 17, 'Harbhajan Singh': 18, 'I Sharma': 19, 'IK Pathan': 20, 'Imran Tahir': 21, 'JDP Oram': 22, 'JH Kallis': 23, 'JJ Bumrah': 24, 'JM Anderson': 25, 'JO Holder': 26, 'JP Duminy': 27, 'JP Faulkner': 28, 'JR Hazlewood': 29, 'K Rabada': 30, 'KA Pollard': 31, 'KMDN Kulasekara': 32, 'Kuldeep Yadav': 33, 'M Morkel': 34, 'M Muralitharan': 35, 'MA Starc': 36, 'MA Wood': 37, 'MG Johnson': 38, 'MJ Santner': 39, 'MM Ali': 40, 'MM Patel': 41, 'MP Stoinis': 42, 'Mashrafe Mortaza': 43, 'Mohammad Amir': 44, 'Mohammad Hafeez': 45, 'Mohammad Irfan': 46, 'Mohammed Shami': 47, 'NLTC Perera': 48, 'NW Bracken': 49, 'Naved-ul-Hasan': 50, 'P Kumar': 51, 'P Utseya': 52, 'PD Collingwood': 53, 'PJ Cummins': 54, 'R Ashwin': 55, 'R Rampaul': 56, 'RA Jadeja': 57, 'S Randiv': 58, 'SCJ Broad': 59, 'SK Warne': 60, 'SL Malinga': 61, 'SM Pollock': 62, 'SR Watson': 63, 'ST Jayasuriya': 64, 'Saeed Ajmal': 65, 'Shahid Afridi': 66, 'Shoaib Akhtar': 67, 'Shoaib Malik': 68, 'TA Boult': 69, 'TG Southee': 70, 'TM Dilshan': 71, 'Umar Gul': 72, 'V Sehwag': 73, 'WPUJC Vaas': 74, 'Wahab Riaz': 75, 'Waqar Younis': 76, 'Wasim Akram': 77, 'Z Khan': 78

# %%
df['Batsman']=label['Batsman'].fit_transform(df['Batsman'])

# %%
df['Batsman'].unique()
# Out:
# array([3, 5, 1, 2, 4, 0])

# %%
df
# Out:
#      Batsman  Versus Player  Innings  Balls  Outs  Runs  \
# 0          3             10       22    296     7   199
# 1          3             16        5     58     2    31
# 2          3             14        6     71     0    71
# 3          3             67       11    165     4   138
# 4          3             62        8     76     5    13
# ..       ...            ...      ...    ...   ...   ...
# 116        0             71       11     92     3    98
# 117        0             75       11    129     0   130
# 118        0             78        9    112     0    91
# 119        0             47        2     28     1    35
# 120        2             60        2     31     0    16
#
#              Bowling Style  5 wkts in an Innings  Bowling Avg
# 0           Right Arm Fast                     9        23.36
# 1    Right Arm Fast-Medium                     7        22.02
# 2           Right Arm Fast                     3        25.95
# ...

# %%
df['Bowling Style']=label['Bowling Style'].fit_transform(df['Bowling Style'])

# %%
df
# Out:
#      Batsman  Versus Player  Innings  Balls  Outs  Runs  Bowling Style  \
# 0          3             10       22    296     7   199              6
# 1          3             16        5     58     2    31              8
# 2          3             14        6     71     0    71              6
# 3          3             67       11    165     4   138              6
# 4          3             62        8     76     5    13              8
# ..       ...            ...      ...    ...   ...   ...            ...
# 116        0             71       11     92     3    98             15
# 117        0             75       11    129     0   130              0
# 118        0             78        9    112     0    91              5
# 119        0             47        2     28     1    35              6
# 120        2             60        2     31     0    16              9
#
#      5 wkts in an Innings  Bowling Avg
# 0                       9        23.36
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop([ 'Outs', 'Runs'],axis=1)

# %%
y=df[['Outs', 'Runs']]

# %%
y
# Out:
#      Outs  Runs
# 0       7   199
# 1       2    31
# 2       0    71
# 3       4   138
# 4       5    13
# ..    ...   ...
# 116     3    98
# 117     0   130
# 118     0    91
# 119     1    35
# 120     0    16
#
# [121 rows x 2 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
ypred1=dt.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred1)
# Out:
# 0.2398856773606986

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(xtest)

# %%
r2_score(ytest,ypred)
# Out:
# 0.48196863666198364

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb = GradientBoostingRegressor()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error

# %%
mean_squared_error(ytest,ypred)
mean_absolute_error(ytest,ypred)
root_mean_squared_error(ytest,ypred)
# Out:
# 13.266588201437738

# %%
score=lr.predict([[5,77,5,20,0,6,23.52]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
score
# Out:
# array([[ 0.83223756, 33.93389042]])

# %%
import pickle as pickle

# %%
with open('linear_model.pkl', 'wb') as file:
    pickle.dump(lr, file)

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
with open('linear_model.pkl', 'wb') as model_file:
    pickle.dump((lr, label), model_file)

# %%
# %%writefile app.py
import streamlit as st
# Out:
# Writing app.py

# %%
import streamlit as st

# %%
st.title('Runs Predictor')
# Out:
# 2025-01-14 07:34:03.792 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-14 07:34:04.850
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-01-14 07:34:04.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !pip install pyngrok

# %%
df

# %%
Batsman=st.selectbox('Batsman',options=label['Batsman'].classes_)
Versus_Player=st.selectbox('Versus Player',options=label['Versus Player'].classes_)
Bowling_Style=st.selectbox('Bowling Style',options=label['Bowling Style'].classes_)
Innings = st.number_input("Innings", min_value=1.0)
Balls = st.number_input("Balls", min_value=1.0)
five_wkts=st.number_input("Five Wicket Haul",min_value=0.0)
Bowling_Avg=st.number_input("Bowling Average")

# %%
batsman_enccoded = label['Batsman'].transform([Batsman])[0]
Versus_Player_encoded = label['Versus Player'].transform([Versus_Player])[0]
bowling_action_encoded=label['Bowling Style'].transform([Bowling_Style])[0]

# %%
input_data = [[batsman_enccoded, Versus_Player_encoded,Innings,Balls,
       bowling_action_encoded, five_wkts,Bowling_Avg]]

# %%
if st.button("Predict"):
    prediction = lr.predict(input_data)
    st.write("Predicted Value:", prediction[0])

# %%
# !streamlit run app.py
